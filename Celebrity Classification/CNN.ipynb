# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import cv2

# %%
img1 = cv2.imread('001_c04300ef.jpg')
img1
# Out:
# array([[[  5,  10,  13],
#         [ 10,  15,  18],
#         [ 25,  30,  33],
#         ...,
#         [158, 149, 145],
#         [161, 149, 147],
#         [158, 146, 144]],
#
#        [[ 10,  15,  18],
#         [ 31,  36,  39],
#         [ 49,  54,  57],
#         ...,
#         [159, 150, 146],
#         [162, 150, 148],
#         [159, 147, 145]],
#
#        [[ 23,  28,  31],
#         [ 45,  50,  53],
#         [ 54,  59,  62],
#         ...,
#         [158, 149, 145],
#         [158, 149, 145],
#         [156, 147, 143]],
#
#        ...,
#
#        [[ 86,  79,  76],
#         [ 87,  80,  77],
#         [ 87,  80,  77],
#         ...,
#         [227, 223, 242],
#         [228, 224, 243],
#         [228, 224, 243]],
#
#        [[ 86,  81,  78],
#         [ 86,  81,  78],
#         [ 87,  82,  81],
#         ...,
#         [228, 224, 243],
#         [228, 224, 243],
#         [228, 224, 243]],
#
#        [[ 85,  80,  77],
#         [ 85,  80,  77],
#         [ 86,  81,  80],
# ...

# %%
img2 = cv2.imread('001_fe3347c0.jpg')
img2
# Out:
# array([[[249, 228, 226],
#         [249, 228, 226],
#         [251, 228, 226],
#         ...,
#         [ 89, 102, 128],
#         [ 74,  87, 113],
#         [ 80,  95, 121]],
#
#        [[249, 228, 226],
#         [249, 228, 226],
#         [251, 228, 226],
#         ...,
#         [ 99, 112, 138],
#         [ 92, 107, 133],
#         [ 64,  79, 105]],
#
#        [[249, 228, 226],
#         [249, 228, 226],
#         [249, 228, 226],
#         ...,
#         [ 76,  89, 115],
#         [ 98, 113, 139],
#         [ 86, 101, 127]],
#
#        ...,
#
#        [[105,  92, 106],
#         [ 96,  83,  97],
#         [100,  87, 103],
#         ...,
#         [ 10,  12,  30],
#         [ 16,  18,  36],
#         [ 14,  16,  34]],
#
#        [[ 99,  86, 100],
#         [ 95,  82,  96],
#         [ 99,  86, 102],
#         ...,
#         [ 15,  17,  35],
#         [ 16,  18,  36],
#         [ 14,  16,  34]],
#
#        [[102,  89, 103],
#         [100,  87, 101],
#         [109,  96, 112],
# ...

# %%
img3 = cv2.imread('002_85eab275.jpg')
img3
# Out:
# array([[[ 57,  68,  66],
#         [ 57,  68,  66],
#         [ 57,  68,  65],
#         ...,
#         [  1,   3,  13],
#         [  2,   4,  12],
#         [  3,   5,  13]],
#
#        [[ 57,  68,  66],
#         [ 57,  68,  66],
#         [ 57,  68,  66],
#         ...,
#         [  0,   2,  12],
#         [  2,   4,  12],
#         [  3,   5,  13]],
#
#        [[ 57,  67,  67],
#         [ 57,  68,  66],
#         [ 57,  68,  66],
#         ...,
#         [  0,   2,  10],
#         [  1,   3,  11],
#         [  3,   5,  13]],
#
#        ...,
#
#        [[ 55,  87,  98],
#         [ 55,  87,  98],
#         [ 54,  86,  97],
#         ...,
#         [ 38,  68, 133],
#         [ 38,  71, 134],
#         [ 38,  71, 134]],
#
#        [[ 56,  88, 101],
#         [ 56,  88, 101],
#         [ 55,  87, 100],
#         ...,
#         [ 32,  62, 127],
#         [ 32,  65, 128],
#         [ 35,  68, 131]],
#
#        [[ 57,  89, 102],
#         [ 56,  88, 101],
#         [ 56,  88, 101],
# ...

# %%
img4 = cv2.imread('002_8f8da10e.jpg')
img4
# Out:
# array([[[ 64, 138, 166],
#         [ 58, 132, 160],
#         [ 66, 135, 168],
#         ...,
#         [ 12,  15,  29],
#         [ 14,  16,  34],
#         [  7,   9,  27]],
#
#        [[ 73, 146, 174],
#         [ 71, 144, 172],
#         [ 63, 132, 165],
#         ...,
#         [  6,   9,  24],
#         [ 16,  18,  36],
#         [  9,  11,  29]],
#
#        [[ 78, 148, 177],
#         [ 68, 138, 167],
#         [ 64, 131, 164],
#         ...,
#         [  5,   7,  25],
#         [ 23,  24,  44],
#         [ 10,  11,  31]],
#
#        ...,
#
#        [[ 14,  45, 106],
#         [  6,  35,  96],
#         [ 11,  36,  98],
#         ...,
#         [  0,   9,  52],
#         [  2,  10,  57],
#         [ 19,  29,  76]],
#
#        [[ 13,  42, 103],
#         [  9,  37,  98],
#         [ 20,  44, 104],
#         ...,
#         [  1,  10,  54],
#         [  9,  16,  65],
#         [  9,  19,  67]],
#
#        [[  2,  31,  92],
#         [  8,  36,  97],
#         [ 10,  34,  94],
# ...

# %%
img5 = cv2.imread('002_cc1b9701.jpg')
img5
# Out:
# array([[[ 21,  22,  18],
#         [ 21,  22,  18],
#         [ 25,  21,  20],
#         ...,
#         [ 40,  40,  46],
#         [ 40,  41,  45],
#         [ 37,  38,  42]],
#
#        [[ 20,  21,  17],
#         [ 19,  20,  16],
#         [ 23,  19,  18],
#         ...,
#         [ 41,  41,  47],
#         [ 42,  43,  47],
#         [ 37,  38,  42]],
#
#        [[ 19,  20,  16],
#         [ 19,  20,  16],
#         [ 22,  18,  17],
#         ...,
#         [ 46,  46,  52],
#         [ 44,  45,  49],
#         [ 37,  38,  42]],
#
#        ...,
#
#        [[ 88,  94, 135],
#         [102, 109, 148],
#         [119, 125, 162],
#         ...,
#         [201, 216, 242],
#         [194, 215, 243],
#         [180, 201, 232]],
#
#        [[ 94,  99, 138],
#         [110, 115, 154],
#         [129, 132, 170],
#         ...,
#         [208, 223, 249],
#         [197, 218, 245],
#         [178, 200, 228]],
#
#        [[ 99, 104, 143],
#         [116, 122, 159],
#         [137, 140, 178],
# ...

# %%
img6 = cv2.imread()
